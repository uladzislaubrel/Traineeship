# %% [markdown]
# ## Датасет собран из базы данных переписи 1994 года и содержит данные о доходах.
# ### Информация о данных:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Проведите анализ данных при помощи Pandas выполнив поставленные задачи.
# ####

# %%
import pandas as pd
import numpy as np

# %%
# загружаем датасет
data = pd.read_csv("./data/adult.data.csv")
len(data)
# Out:
# 32561

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# **1. Посчитайте, сколько мужчин и женщин (признак *sex*) представлено в этом датасете**

# %%
print(f'{len(data[data['sex'] == 'Female'])} женщин')
print(f'{len(data[data['sex'] == 'Male'])} мужчин')
# Out:
# 10771 женщин
# 21790 мужчин

# %% [markdown]
# **2. Каков средний возраст мужчин (признак *age*) по всему датасету?**

# %%
print(f"Средний возраст: {data[data['sex'] == 'Male'].age.mean()}")
# Out:
# Средний возраст: 39.43354749885268

# %%
data[data['sex'] == 'Male'].describe() #39,433547
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  21790.000000  2.179000e+04   21790.000000  21790.000000  21790.000000
# mean      39.433547  1.917714e+05      10.102891   1329.370078    100.213309
# std       13.370630  1.067407e+05       2.662630   8326.312095    429.763097
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       29.000000  1.182008e+05       9.000000      0.000000      0.000000
# 50%       38.000000  1.801400e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.411462e+05      13.000000      0.000000      0.000000
# max       90.000000  1.455435e+06      16.000000  99999.000000   3770.000000
#
#        hours-per-week
# count    21790.000000
# mean        42.428086
# std         12.119755
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         49.000000
# max         99.000000

# %% [markdown]
# **3. Какова доля граждан Соединенных Штатов (признак *native-country*)?**

# %%
result = (data['native-country'] == 'United-States').mean()
result
# Out:
# np.float64(0.895857006848684)

# %% [markdown]
# **4-5. Рассчитайте среднее значение и среднеквадратичное отклонение возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год**

# %%
high = data[data['salary'] == '>50K'] # ['age'].mean()
print(f'{high['age'].mean()} средний возраст людей с высокой зп')
print(f'{high['age'].std()} среднеквадратичное отклонение возраста людей с высокой зп')
low = data[data['salary'] == '<=50K']
print(f'{low['age'].mean()} средний возраст людей с невысокой зп')
print(f'{low['age'].std()}среднеквадратичное отклонение возраста людей с невысокой зп')
# Out:
# 44.24984058155847 средний возраст людей с высокой зп
# 10.51902771985177 среднеквадратичное отклонение возраста людей с высокой зп
# 36.78373786407767 средний возраст людей с невысокой зп
# 14.020088490824813среднеквадратичное отклонение возраста людей с невысокой зп

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
print(high["education"].isin(["Bachelors","Prof-school","Assoc-acdm","Assoc-voc","Masters","Doctorate"]).all())
edu = high["education"].isin(["Bachelors","Prof-school","Assoc-acdm","Assoc-voc","Masters","Doctorate"]).sum()
al = high["education"].isin(["Bachelors","Prof-school","Assoc-acdm","Assoc-voc","Masters","Doctorate"]).count()
print(f'всего {al} а с нужным образованием {edu}')
print(f'Доля = {edu/al}')
# Out:
# False
# всего 7841 а с нужным образованием 4535
# Доля = 0.5783701058538452

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Asian-Pac-Islander*.** #90 лет

# %%
data.groupby(by='race')['age'].describe()
# Out:
#                       count       mean        std   min   25%   50%   75%  \
# race
# Amer-Indian-Eskimo    311.0  37.173633  12.447130  17.0  28.0  35.0  45.5
# Asian-Pac-Islander   1039.0  37.746872  12.825133  17.0  28.0  36.0  45.0
# Black                3124.0  37.767926  12.759290  17.0  28.0  36.0  46.0
# Other                 271.0  33.457565  11.538865  17.0  25.0  31.0  41.0
# White               27816.0  38.769881  13.782306  17.0  28.0  37.0  48.0
#
#                      max
# race
# Amer-Indian-Eskimo  82.0
# Asian-Pac-Islander  90.0
# Black               90.0
# Other               77.0
# White               90.0

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
married = data[data['marital-status'].isin(['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse'])]
rich_mar = married[married['salary'] == '>50K']
print(f'женатых богатых {len(rich_mar)} из {len(married)}')
unmarried = data[~data['marital-status'].isin(['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse'])]
rich_unmar = unmarried[unmarried['salary'] == '>50K']
print(f'холостых богатых {len(rich_unmar)} из {len(unmarried)}')
# Out:
# женатых богатых 6736 из 15417
# холостых богатых 1105 из 17144

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
max_hours = data['hours-per-week'].max()
people_max_work = data[data['hours-per-week'] == max_hours]
print(f'макс часов {max_hours}')
print(f'людей работающих макс часы {len(people_max_work)}')
p_m_w_rich = people_max_work[people_max_work['salary'] == '>50K']
print(f'богатых из них {len(p_m_w_rich)/len(people_max_work)* 100} %')
# Out:
# макс часов 99
# людей работающих макс часы 85
# богатых из них 29.411764705882355 %

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
rich = data[data['salary'] == '>50K']
work_rich = rich.groupby(by='native-country')['hours-per-week'].mean()
print(f'среднее количество часов зарабатывающих много {work_rich}')
poor =  data[data['salary'] == '<=50K']
work_poor = poor.groupby(by='native-country')['hours-per-week'].mean()
print(f'среднее количество часов зарабатывающих НЕмного {work_poor}')
# Out:
# среднее количество часов зарабатывающих много native-country
# ?                     45.547945
# Cambodia              40.000000
# Canada                45.641026
# China                 38.900000
# Columbia              50.000000
# Cuba                  42.440000
# Dominican-Republic    47.000000
# Ecuador               48.750000
# El-Salvador           45.000000
# England               44.533333
# France                50.750000
# Germany               44.977273
# Greece                50.625000
# Guatemala             36.666667
# Haiti                 42.750000
# Honduras              60.000000
# Hong                  45.000000
# Hungary               50.000000
# India                 46.475000
# Iran                  47.500000
# Ireland               48.000000
# Italy                 45.400000
# Jamaica               41.100000
# Japan                 47.958333
# Laos                  40.000000
# Mexico                46.575758
# Nicaragua             37.500000
# ...

# %% [markdown]
# **11.Сгруппируйте людей по возрастным группам *young*, *adult*, *retiree*, где:**
# * *young* соответствует 16-35 лет
# * *adult* - 35-70 лет
# * *retiree* - 70-100 лет
#
# **Проставьте название соответсвтуещей группы для каждого человека в новой колонке AgeGroup**

# %%
data['age_group'] = pd.cut(data['age'], 
                           bins=[16, 35, 70, 100], 
                           labels=['young', 'adult', 'retiree'],
                           include_lowest=True)
print(data[['age','age_group']])
data.loc[120:170, ['age', 'age_group']]
# Out:
#        age age_group
# 0       39     adult
# 1       50     adult
# 2       38     adult
# 3       53     adult
# 4       28     young
# ...    ...       ...
# 32556   27     young
# 32557   40     adult
# 32558   58     adult
# 32559   22     young
# 32560   52     adult
#
# [32561 rows x 2 columns]
#      age age_group
# 120   21     young
# 121   40     adult
# 122   30     young
# 123   29     young
# 124   19     young
# 125   47     adult
# 126   20     young
# 127   31     young
# 128   35     young
# 129   39     adult
# 130   28     young
# 131   24     young
# 132   38     adult
# 133   37     adult
# 134   46     adult
# 135   38     adult
# 136   43     adult
# 137   27     young
# 138   20     young
# 139   49     adult
# 140   61     adult
# 141   27     young
# 142   19     young
# 143   45     adult
# 144   70     adult
# 145   31     young
# 146   22     young
# 147   36     adult
# 148   64     adult
# 149   43     adult
# 150   47     adult
# 151   34     young
# ...

# %% [markdown]
# **12-13. Определите количество зарабатывающих >50K в каждой из возрастных групп (колонка AgeGroup), а также выведите название возрастной группы, в которой чаще зарабатывают больше 50К (>50K)**

# %%
age_rich = data[data['salary'] == '>50K']['age_group'].value_counts()
print(age_rich)
print(f'Больше других зарабатывают {age_rich.idxmax()}')
# Out:
# age_group
# adult      6042
# young      1705
# retiree      94
# Name: count, dtype: int64
# Больше других зарабатывают adult

# %% [markdown]
# **14. Сгруппируйте людей по типу занятости (колонка occupation) и определите количество людей в каждой группе. После чего напишите функциюю фильтрации filter_func, которая будет возвращать только те группы, в которых средний возраст (колонка age) не больше 40 и в которых все работники отрабатывают более 5 часов в неделю (колонка hours-per-week)**

# %%
def filter_func(group: pd.DataFrame):
    return group["age"].mean() <= 40 and group["hours-per-week"].min() > 5

grouped = data.groupby("occupation")
print(f"Кол-во людей в каждой группе:\n{grouped.size()}")
print(f"Группы, в которых средний возраст меньше 40 и работают более 5 часов в неделю:\n{grouped.filter(filter_func)[["age", "hours-per-week"]]}")
# Out:
# Кол-во людей в каждой группе:
# occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64
# Группы, в которых средний возраст меньше 40 и работают более 5 часов в неделю:
#        age  hours-per-week
# 442     24              40
# 1300    29              60
# 14613   39              50
# 16111   24              40
# 18034   34              40
# 18644   23              40
# 18769   30              48
# 25799   46              40
# 32316   23               8
